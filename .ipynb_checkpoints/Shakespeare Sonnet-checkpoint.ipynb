# %% [markdown]
# # 3: Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

import os
import string
import re # regular expression
import HMM as hmm
# import keras.preprocessing.text

# %%
def parse_map(lines):
    counter = 0
    x = []
    mapping = {}

    for line in lines:
        elem = []
        
        for word in line:
            # replace the following characters with '', i.e. remove them
            #word = re.sub(r'[]_`\', '', word)
            word = re.sub(r'[^\w]', '', word).lower()
                          # {|\}0123456789^\n\t
            # convert all words to lower case
            word = word.lower()
            
            if word not in mapping:
                mapping[word] = counter
                counter += 1
            elem.append(mapping[word])
        x.append(elem)

    return x, mapping

def mapping_reverser(mapping):
    mapping_r = {}

    for key in mapping:
        mapping_r[mapping[key]] = key

    return mapping_r

# %%
# get syllable info

syllable = open('data/Syllable_dictionary.txt','r')
syllable_dic = {}
    
for line in syllable:
    line = line.split()
    word = line[0]
    rem = line[1: len(line)]
    syllable_dic[word] = rem

# %%
def open_file(files):
    '''Keeps track of lines in an array and words in a dictionary mapping to word frequency'''
    words = {}
    lines = [] 
    
    for f in files:
        file = open(f, 'r')
        
        for line in file:
            if  len(line) < 10:
                continue
            line = line.strip()
            line = line.lower() # turn everything into lower case
            line = "".join(l for l in line if l not in string.punctuation) # take out all punctuation
            line = line.split() # split the line and then add it to lines

            lines.append(line)

            # increase frequency if item already exists, create it if it doesn't
            for w in line:
                try:
                    words[w] += 1
                except KeyError:
                    words[w] = 1
    
    return words, lines

# %%
words, lines = open_file(["data/shakespeare.txt", "data/spenser.txt"]) 
x, mapping =  parse_map(lines)

# %% [markdown]
# # Rhyme

# %%
import nltk
# nltk.download('cmudict')
d = nltk.corpus.cmudict.dict()
rhyme_dic = {} # only contain words with stressed ending
for word in words:
    try:
        for syl in reversed(d[word][0]):
            # if it's the ending rhyme
            if syl[-1] == '1' or syl[-1] == '0':
                if syl[-1] == '1':
                    if syl[:-1] in rhyme_dic:
                        rhyme_dic[syl[:-1]] = rhyme_dic[syl[:-1]] + [word]
                    else:
                        rhyme_dic[syl[:-1]] = [word]
                break
    except Exception as e:
        print(e)
print(rhyme_dic)
# Out:
# '1'
# 'beautys'
# 'riper'
# 'feedst'
# 'selfsubstantial'
# 'buriest'
# 'churl'
# 'makst'
# 'niggarding'
# 'glutton'
# '2'
# 'alleating'
# 'thriftless'
# 'couldst'
# 'feelst'
# '3'
# 'viewest'
# 'renewest'
# 'unbless'
# 'uneared'
# 'tillage'
# 'selflove'
# '4'
# 'unthrifty'
# 'loveliness'
# 'beauteous'
# 'bounteous'
# 'profitless'
# 'usurer'
# 'canst'
# 'tombed'
# '5'
# 'neverresting'
# 'oersnowed'
# 'bareness'
# '6'
# 'selfkilled'
# 'happies'
# 'thats'
# 'refigured'
# 'shouldst'
# 'selfwilled'
# '7'
# 'newappearing'
# 'steepup'
# 'highmost'
# 'reeleth'
# 'duteous'
# 'unlooked'
# 'diest'
# '8'
# 'lovst'
# 'receivst'
# 'welltuned'
# 'singleness'
# '9'
# 'consumst'
# 'makeless'
# 'unthrift'
# 'murdrous'
# '10'
# 'bearst'
# 'unprovident'
# 'gainst'
# 'stickst'
# 'ruinate'
# 'kindhearted'
# '11'
# 'growst'
# 'departest'
# 'youngly'
# 'bestowst'
# 'mayst'
# 'convertest'
# 'threescore'
# 'barrenly'
# '12'
# 'silvered'
# 'oer'
# 'erst'
# 'girded'
# 'bristly'
# '13'
# 'honour'
# 'unthrifts'
# '14'
# 'methinks'
# 'dearths'
# 'wouldst'
# '15'
# 'presenteth'
# 'nought'
# 'whereon'
# 'selfsame'
# 'vaunt'
# 'inconstant'
# 'debateth'
# 'engraft'
# '16'
# 'wherefore'
# 'liker'
# '17'
# 'yellowed'
# 'metre'
# '18'
# 'untrimmed'
# 'owst'
# 'wandrest'
# '19'
# 'longlived'
# 'fleetst'
# 'whateer'
# 'swiftfooted'
# '20'
# 'womans'
# 'womens'
# 'gazeth'
# 'amazeth'
# 'adoting'
# '21'
# 'couplement'
# 'aprils'
# 'rondure'
# '22'
# 'furrows'
# 'seemly'
# 'raiment'
# 'thyself'
# 'gavst'
# '23'
# 'unperfect'
# 'oercharged'
# 'burthen'
# 'presagers'
# '24'
# 'stelled'
# 'bosoms'
# 'wherethrough'
# '25'
# 'favour'
# 'favourites'
# 'famoused'
# '26'
# 'vassalage'
# 'embassage'
# '27'
# 'respose'
# 'bodys'
# 'sightless'
# '28'
# 'debarred'
# 'eithers'
# 'swartcomplexioned'
# 'twire'
# 'gildst'
# 'griefs'
# '29'
# 'beweep'
# 'bootless'
# 'haply'
# '30'
# 'dateless'
# 'forebemoaned'
# '31'
# 'stoln'
# '32'
# 'wellcontented'
# 'resurvey'
# 'bettring'
# 'vouchsafe'
# 'equipage'
# '33'
# 'anon'
# 'basest'
# 'splendour'
# 'alack'
# 'disdaineth'
# 'staineth'
# '34'
# 'didst'
# 'oertake'
# 'bravry'
# 'stormbeaten'
# 'physic'
# 'offences'
# '35'
# 'salving'
# 'accessary'
# 'sourly'
# '36'
# 'separable'
# 'bewailed'
# '37'
# 'engrafted'
# '38'
# 'pourst'
# 'aught'
# 'whos'
# 'rhymers'
# 'invocate'
# '39'
# 'ist'
# 'deservst'
# 'teachest'
# '40'
# 'hadst'
# 'receivest'
# 'usest'
# 'deceivest'
# 'wilful'
# 'refusest'
# 'spites'
# '41'
# 'mightst'
# 'forbear'
# '42'
# 'knowst'
# 'suffring'
# 'heres'
# '43'
# 'unrespected'
# 'unseeing'
# '44'
# '45'
# 'presentabsent'
# 'recured'
# '46'
# 'impanelled'
# 'moiety'
# '47'
# 'famished'
# 'awakes'
# '48'
# 'thievish'
# '49'
# 'uprear'
# '50'
# 'plods'
# 'dully'
# 'wretch'
# '51'
# 'offence'
# 'perfectst'
# 'neigh'
# 'wilfulslow'
# '52'
# 'uplocked'
# 'carcanet'
# 'specialblest'
# '53'
# 'whereof'
# 'foison'
# '54'
# 'odour'
# 'unwooed'
# 'odours'
# '55'
# 'unswept'
# 'besmeared'
# 'sluttish'
# 'broils'
# 'alloblivious'
# '56'
# 'fulness'
# 'dulness'
# '57'
# 'worldwithoutend'
# '58'
# 'sufferance'
# 'privilage'
# 'selfdoing'
# '59'
# 'labouring'
# '60'
# 'pebbled'
# 'wherewith'
# '61'
# 'slumbers'
# 'sendst'
# '62'
# 'possesseth'
# 'beated'
# 'chopt'
# 'selfloving'
# '63'
# 'oerworn'
# 'steepy'
# 'hes'
# '64'
# 'richproud'
# 'outworn'
# 'downrased'
# '65'
# 'oersways'
# 'wrackful'
# 'battring'
# '66'
# 'jollity'
# 'shamefully'
# 'strumpeted'
# 'tonguetied'
# 'doctorlike'
# 'miscalled'
# '67'
# 'impiety'
# 'beggared'
# '68'
# 'sepulchres'
# 'anothers'
# '69'
# 'churls'
# 'matcheth'
# '70'
# 'presentst'
# '71'
# 'vilest'
# '72'
# '73'
# 'seest'
# 'fadeth'
# 'perceivst'
# '74'
# 'reviewest'
# 'wretchs'
# '75'
# 'sweetseasoned'
# 'twixt'
# 'enjoyer'
# 'filching'
# 'gluttoning'
# '76'
# '77'
# '78'
# 'poesy'
# 'learneds'
# '79'
# 'behaviour'
# '80'
# 'shallowest'
# 'soundless'
# '81'
# 'oerread'
# 'breathers'
# '82'
# 'attaint'
# 'oerlook'
# 'timebettering'
# 'truetelling'
# '83'
# '84'
# 'immured'
# 'dignifies'
# '85'
# 'unlettered'
# 'hindmost'
# '86'
# 'inhearse'
# 'compeers'
# '87'
# 'swerving'
# '88'
# 'attainted'
# 'doublevantage'
# '89'
# 'lameness'
# 'wronk'
# '90'
# 'afterloss'
# 'scaped'
# 'rearward'
# 'purposed'
# '91'
# 'humour'
# '92'
# 'blessedfair'
# '93'
# 'manys'
# '94'
# 'tibey'
# 'outbraves'
# 'sourest'
# '95'
# 'dispraise'
# 'illused'
# '96'
# 'wantonness'
# 'throned'
# 'gazers'
# '97'
# 'freezings'
# 'decembers'
# 'wombs'
# 'unfathered'
# '98'
# 'proudpied'
# 'lilys'
# '99'
# 'fearfully'
# 'colour'
# '100'
# 'forgetst'
# 'spendst'
# 'resty'
# 'preventst'
# '101'
# '102'
# 'merchandized'
# 'esteeming'
# 'philomel'
# 'burthens'
# '103'
# 'overgoes'
# '104'
# 'unbred'
# '105'
# '106'
# 'wights'
# 'blazon'
# 'prefiguring'
# '107'
# 'incertainties'
# '108'
# '109'
# 'preposterously'
# '110'
# 'blenches'
# '111'
# 'dyers'
# '112'
# 'oergreen'
# 'steeled'
# 'abysm'
# 'adders'
# 'flatterer'
# '113'
# 'effectually'
# 'rudst'
# 'deformedst'
# 'maketh'
# '114'
# 'saith'
# 'cherubins'
# 'greeing'
# '115'
# 'millioned'
# 'sharpst'
# 'altring'
# 'incertainty'
# '116'
# 'everfixed'
# 'tempests'
# 'wandring'
# '117'
# 'scanted'
# 'whereto'
# 'dearpurchased'
# 'wilfulness'
# 'wakened'
# '118'
# 'neercloying'
# 'meetness'
# '119'
# 'limbecks'
# '120'
# 'unkindness'
# 'yhave'
# '121'
# 'salutation'
# 'sportive'
# 'frailer'
# '122'
# 'charactered'
# 'forgetfulness'
# '123'
# 'wondring'
# '124'
# 'builded'
# 'thralled'
# 'shortnumbered'
# '125'
# 'weret'
# 'extern'
# 'honouring'
# 'savour'
# 'thrivers'
# 'oblation'
# 'suborned'
# '126'
# 'showst'
# 'goest'
# 'quietus'
# '127'
# 'fairing'
# 'profaned'
# '128'
# 'playst'
# 'swayst'
# '129'
# '130'
# 'damasked'
# '131'
# 'tyrannous'
# '132'
# 'beseem'
# '133'
# 'beshrew'
# 'sweetst'
# 'whoeer'
# 'rigour'
# 'gaol'
# '134'
# 'covetous'
# 'suretylike'
# 'putst'
# '135'
# 'overplus'
# 'addeth'
# 'beseechers'
# '136'
# 'lovesuit'
# 'fulfil'
# '137'
# 'overpartial'
# '138'
# 'untutored'
# 'unlearned'
# 'falsespeaking'
# '139'
# 'needst'
# 'oerpressed'
# '140'
# 'pitywanting'
# 'illwresting'
# 'slanderers'
# '141'
# '142'
# 'reproving'
# 'importune'
# 'selfexample'
# '143'
# 'huswife'
# 'prizing'
# 'runst'
# '144'
# 'worser'
# 'tempteth'
# '145'
# '146'
# 'inheritors'
# 'theres'
# '147'
# 'nurseth'
# 'franticmad'
# '148'
# 'censures'
# 'aright'
# 'keepst'
# 'wellseeing'
# '149'
# 'alltyrant'
# 'hateth'
# 'frownst'
# 'lourst'
# '150'
# 'insufficiency'
# 'warrantise'
# 'unworthiness'
# '151'
# '152'
# 'bedvow'
# '153'
# 'dians'
# 'lovekindling'
# 'valleyfountain'
# 'seeting'
# 'newfired'
# 'withal'
# 'thither'
# 'hied'
# 'distempered'
# '154'
# 'lovegod'
# 'heartinflaming'
# 'votary'
# 'quenched'
# 'discased'
# 'deaddoing'
# 'closebleeding'
# 'bathd'
# 'longlacked'
# 'unquiet'
# 'lovepined'
# 'sithens'
# 'woxen'
# 'lurkest'
# 'succour'
# 'humbless'
# 'entreat'
# 'baseness'
# 'ravished'
# 'fancys'
# 'endite'
# 'dumpish'
# 'cheerless'
# 'dight'
# 'wrongest'
# 'sdeigne'
# 'portliness'
# 'boldened'
# 'selfpleasing'
# 'lusts'
# 'durefull'
# 'dints'
# 'mazed'
# 'ensample'
# 'longwhile'
# 'thimage'
# 'persever'
# 'mought'
# 'likest'
# 'unrighteous'
# 'makest'
# 'lordeth'
# 'freewill'
# 'scorning'
# 'tyraness'
# 'comptroll'
# 'renewth'
# 'persueth'
# 'unpityed'
# 'assoyle'
# 'surcease'
# 'heartthrilling'
# 'treasons'
# 'guileful'
# 'eyen'
# 'tabide'
# 'captiving'
# 'graceth'
# 'embaseth'
# 'descry'
# 'remembreth'
# 'lothsome'
# 'drossy'
# 'lowliness'
# 'abondond'
# 'needeth'
# 'belay'
# 'enurd'
# 'plaints'
# 'tradefull'
# 'indias'
# 'saphires'
# 'forhead'
# 'weene'
# 'unwarily'
# 'stonished'
# 'archers'
# 'misintended'
# 'embase'
# 'colours'
# 'eyeglances'
# 'pleasance'
# 'craftsmans'
# 'thereto'
# 'runneth'
# 'drizling'
# 'plaint'
# 'resounded'
# 'mongst'
# 'disobeys'
# 'reighneth'
# 'lioness'
# 'defiled'
# 'cruelness'
# 'meekness'
# 'tadorn'
# 'recure'
# 'thauthor'
# 'godess'
# 'wooers'
# 'unreave'
# 'thimportune'
# 'rend'
# 'unwares'
# 'intreat'
# 'doubtfully'
# 'meede'
# 'pricketh'
# 'firbloom'
# 'broomflower'
# 'sith'
# 'beseen'
# 'fleshs'
# 'thessalian'
# 'revengeful'
# 'quoth'
# 'meeds'
# 'therewith'
# 'sohot'
# 'depraves'
# 'scath'
# 'allurement'
# 'thralls'
# 'embrew'
# 'abhored'
# 'thanvil'
# 'frieseth'
# 'faedry'
# 'aread'
# 'theaccomplishment'
# 'troublous'
# 'whenas'
# 'plast'
# 'carefull'
# 'comfortless'
# 'pensiveness'
# 'covetize'
# 'starvd'
# 'seemeth'
# 'langor'
# 'aswagement'
# 'shewed'
# 'extermities'
# 'dispise'
# 'cunningly'
# 'craftily'
# 'rashly'
# 'arion'
# 'pitty'
# 'blamd'
# 'wonts'
# 'jove'
# 'thundring'
# 'shinedst'
# 'gladness'
# 'whylest'
# 'tincrease'
# 'wretches'
# 'piteous'
# 'foully'
# 'tormenteth'
# 'extremest'
# 'augmenteth'
# 'captived'
# 'lovelearned'
# 'whilest'
# 'warried'
# 'aslake'
# 'tuneless'
# 'despight'
# 'immortally'
# 'visnomy'
# 'abodes'
# 'prefixed'
# 'aswage'
# 'guilefull'
# 'heretics'
# 'contrained'
# 'requite'
# 'thutmost'
# 'cockatrices'
# 'footstool'
# 'priefe'
# 'langour'
# 'excellect'
# 'assayed'
# 'tachieve'
# 'despoiled'
# 'knowen'
# 'languor'
# 'thm'
# 'enbrew'
# 'diversely'
# 'flits'
# 'rues'
# 'greediness'
# 'felly'
# 'pityless'
# 'stoures'
# 'wouds'
# 'lviii'
# 'thassurance'
# 'reposeth'
# 'scorneth'
# 'supposeth'
# 'unstayed'
# 'changeful'
# 'glorys'
# 'faileth'
# 'standeth'
# 'endurence'
# 'misdeem'
# 'outwent'
# 'languishment'
# 'taccuse'
# 'upbrought'
# 'lovd'
# 'compassed'
# 'betokening'
# 'forepast'
# 'glooming'
# 'gladsome'
# 'sufficeth'
# 'damsels'
# 'gillyflowers'
# 'budded'
# 'bellamores'
# 'lillies'
# 'jasmines'
# 'blissing'
# 'plenteous'
# 'disparagement'
# 'matchable'
# 'enlumined'
# 'halftrembling'
# 'harrowed'
# 'worthily'
# 'antick'
# 'valorous'
# 'emprize'
# 'adornd'
# 'coatarmor'
# 'forelock'
# 'misseth'
# 'amearst'
# 'drawen'
# 'youself'
# 'woodbine'
# 'mantleth'
# 'flys'
# 'encage'
# 'framd'
# 'derivd'
# 'elizabeths'
# 'doest'
# 'eek'
# 'quod'
# 'eternize'
# 'paps'
# 'loosly'
# 'juncats'
# 'unvalued'
# 'thereunto'
# 'faery'
# 'fordone'
# 'handmaid'
# 'queene'
# 'heares'
# 'richladen'
# 'soom'
# 'enchased'
# 'lustfull'
# 'sprites'
# 'plights'
# 'venemous'
# 'furies'
# 'snaky'
# 'accursed'
# 'falseforged'
# 'meed'
# 'noyous'
# 'reascend'
# 'thonly'
# 'loveafamished'
# 'disconsolate'
# 'unspotted'
# 'pleasauns'
# {'AH': ['from', 'but', 'bud', 'of', 'much', 'sum', 'blood', 'some', 'sums', 'what', 'must', 'one', 'up', 'son', 'none', 'love', 'such', 'beloved', 'sunk', 'among', 'gusts', 'pluck', 'luck', 'come', 'touched', 'tongue', 'rough', 'buds', 'sometime', 'blunt', 'loves', 'young', 'sun', 'trust', 'dumb', 'done', 'suns', 'once', 'hung', 'thus', 'loved', 'dust', 'enough', 'mud', 'us', 'won', 'dull', 'jump', 'thrust', 'utmost', 'thrusts', 'run', 'crushed', 'cut', 'blush', 'tongues', 'sunset', 'thereof', 'above', 'struck', 'gulls', 'comes', 'front', 'hush', 'insults', 'just', 'dove', 'gust', 'cup', 'shun', 'drugs', 'drunk', 'becomes', 'lust', 'dun', 'become', 'corrupt', 'unjust', 'runs', 'drudge', 'touch', 'brunt', 'repulse', 'cuckoo', 'amongst', 'undone', 'begun', 'spun', 'tough', 'nut', 'trump', 'conduct', 'sunshine', 'dumps', 'hunts', 'floods', 'bunch', 'ones', 'does'], 'IY': ['we', 'increase', 'decease', 'sweet', 'be', 'eat', 'thee', 'besiege', 'deep', 'field', 'weed', 'see', 'she', 'he', 'free', 'deceive', 'leave', 'leads', 'leaves', 'meet', 'leese', 'breed', 'each', 'hear', 'sweets', 'ear', 'weep', 'keep', 'chief', 'least', 'me', 'cease', 'seal', 'trees', 'heat', 'green', 'sheaves', 'bier', 'here', 'lease', 'brief', 'perceive', 'decrease', 'conceit', 'means', 'keeps', 'believe', 'antique', 'breathe', 'keen', 'teeth', 'steals', 'seas', 'hearsay', 'replete', 'seem', 'plead', 'peep', 'eased', 'please', 'these', 'grieve', 'endeared', 'deceased', 'seen', 'streams', 'unseen', 'speak', 'heals', 'grief', 'weak', 'relief', 'deeds', 'grieved', 'plea', 'needs', 'thief', 'steal', 'seat', 'ye', 'sleep', 'dreams', 'sea', 'leap', 'league', 'feast', 'feel', 'greet', 'seek', 'teach', 'beast', 'speed', 'need', 'key', 'feasts', 'cheek', 'deem', 'feeds', 'defeat', 'indeed', 'siege', 'steel', 'achieve', 'fleece', 'weeds', 'seals', 'peace', 'clean', 'proceed', 'yield', 'breathes', 'cheeks', 'exceed', 'lean', 'dream', 'concealed', 'deceived', 'decree', 'eves', 'heed', 'queen', 'esteemed', 'deemed', 'seemed', 'redeem', 'esteem', 'seems', 'three', 'perceived', 'themes', 'cheap', 'breeds', 'receives', 'beams', 'creep', 'decrees', 'weeks', 'appeal', 'diseased', 't', 'feil', 'fee', 'receive', 'impeached', 'reap', 'extreme', 'reeks', 'proceeds', 'east', 'threefold', 'receipt', 'believed', 'pleased', 'sealed', 'female', 'fiend', 'breathed', 'feed', 'disease', 'sees', 'exceeds', 'breach', 'asleep', 'steep', 'heats', 'ease', 'feet', 'meek', 'weave', 'ne', 'conceive', 'seeks', 'sheen', 'eke', 'wheel', 'precept', 'priests', 'appease', 'agree', 'beat', 'unclean', 'leaf', 'tree', 'congealed', 'beasts', 'release', 'meat', 'greece', 'mean', 'leach', 'reveal', 'heal', 'shield', 'mead', 'freeze', 'beats', 'beam', 'degree', 'feels', 'increased', 'bee', 'between', 'fields', 'seed', 'steed'], 'AE': ['that', 'as', 'shall', 'asked', 'an', 'glass', 'back', 'shalt', 'frank', 'sap', 'hand', 'than', 'tract', 'hap', 'hast', 'hath', 'grant', 'at', 'fast', 'past', 'can', 'had', 'have', 'plants', 'stand', 'half', 'chance', 'brag', 'glad', 'man', 'am', 'aspect', 'shadow', 'black', 'hands', 'mans', 'lack', 'sad', 'ranks', 'rack', 'masked', 'thanks', 'shadows', 'land', 'falsehood', 'cast', 'pass', 'lacked', 'hang', 'statues', 'banks', 'stands', 'tanned', 'brass', 'last', 'bad', 'map', 'add', 'rank', 'passed', 'ambush', 'perhaps', 'task', 'sang', 'glance', 'blanks', 'advance', 'thank', 'stamp', 'adjunct', 'lambs', 'lamb', 'laughed', 'lap', 'alas', 'askance', 'brand', 'stamped', 'latch', 'catch', 'tan', 'wrack', 'jacks', 'mad', 'dispatch', 'act', 'bath', 'bands', 'rash', 'laugh', 'address', 'wrath', 'entrap', 'craft', 'badge', 'entrapped', 'ran', 'rapt', 'trance', 'understand', 'mask', 'laughs', 'began', 'strand', 'protract', 'match'], 'AY': ['thereby', 'might', 'die', 'by', 'time', 'thine', 'bright', 'eyes', 'thy', 'lights', 'lies', 'child', 'mine', 'my', 'beguile', 'prime', 'despite', 'live', 'dies', 'why', 'eye', 'quite', 'times', 'light', 'sight', 'climbed', 'like', 'delights', 'chide ...

# %% [markdown]
# # Stress Pattern

# %%
stress_dic = {}
for word in words:
    try:
        stress = ''
        for syl in d[word][0]:
            if syl[-1] == '1':
                stress += '1'
            elif syl[-1] == '0':
                stress += '0'
        stress_dic[word] = stress
    except Exception as e:
        print(e)
print(stress_dic)
# Out:
# '1'
# 'beautys'
# 'riper'
# 'feedst'
# 'selfsubstantial'
# 'buriest'
# 'churl'
# 'makst'
# 'niggarding'
# 'glutton'
# '2'
# 'alleating'
# 'thriftless'
# 'couldst'
# 'feelst'
# '3'
# 'viewest'
# 'renewest'
# 'unbless'
# 'uneared'
# 'tillage'
# 'selflove'
# '4'
# 'unthrifty'
# 'loveliness'
# 'beauteous'
# 'bounteous'
# 'profitless'
# 'usurer'
# 'canst'
# 'tombed'
# '5'
# 'neverresting'
# 'oersnowed'
# 'bareness'
# '6'
# 'selfkilled'
# 'happies'
# 'thats'
# 'refigured'
# 'shouldst'
# 'selfwilled'
# '7'
# 'newappearing'
# 'steepup'
# 'highmost'
# 'reeleth'
# 'duteous'
# 'unlooked'
# 'diest'
# '8'
# 'lovst'
# 'receivst'
# 'welltuned'
# 'singleness'
# '9'
# 'consumst'
# 'makeless'
# 'unthrift'
# 'murdrous'
# '10'
# 'bearst'
# 'unprovident'
# 'gainst'
# 'stickst'
# 'ruinate'
# 'kindhearted'
# '11'
# 'growst'
# 'departest'
# 'youngly'
# 'bestowst'
# 'mayst'
# 'convertest'
# 'threescore'
# 'barrenly'
# '12'
# 'silvered'
# 'oer'
# 'erst'
# 'girded'
# 'bristly'
# '13'
# 'honour'
# 'unthrifts'
# '14'
# 'methinks'
# 'dearths'
# 'wouldst'
# '15'
# 'presenteth'
# 'nought'
# 'whereon'
# 'selfsame'
# 'vaunt'
# 'inconstant'
# 'debateth'
# 'engraft'
# '16'
# 'wherefore'
# 'liker'
# '17'
# 'yellowed'
# 'metre'
# '18'
# 'untrimmed'
# 'owst'
# 'wandrest'
# '19'
# 'longlived'
# 'fleetst'
# 'whateer'
# 'swiftfooted'
# '20'
# 'womans'
# 'womens'
# 'gazeth'
# 'amazeth'
# 'adoting'
# '21'
# 'couplement'
# 'aprils'
# 'rondure'
# '22'
# 'furrows'
# 'seemly'
# 'raiment'
# 'thyself'
# 'gavst'
# '23'
# 'unperfect'
# 'oercharged'
# 'burthen'
# 'presagers'
# '24'
# 'stelled'
# 'bosoms'
# 'wherethrough'
# '25'
# 'favour'
# 'favourites'
# 'famoused'
# '26'
# 'vassalage'
# 'embassage'
# '27'
# 'respose'
# 'bodys'
# 'sightless'
# '28'
# 'debarred'
# 'eithers'
# 'swartcomplexioned'
# 'twire'
# 'gildst'
# 'griefs'
# '29'
# 'beweep'
# 'bootless'
# 'haply'
# '30'
# 'dateless'
# 'forebemoaned'
# '31'
# 'stoln'
# '32'
# 'wellcontented'
# 'resurvey'
# 'bettring'
# 'vouchsafe'
# 'equipage'
# '33'
# 'anon'
# 'basest'
# 'splendour'
# 'alack'
# 'disdaineth'
# 'staineth'
# '34'
# 'didst'
# 'oertake'
# 'bravry'
# 'stormbeaten'
# 'physic'
# 'offences'
# '35'
# 'salving'
# 'accessary'
# 'sourly'
# '36'
# 'separable'
# 'bewailed'
# '37'
# 'engrafted'
# '38'
# 'pourst'
# 'aught'
# 'whos'
# 'rhymers'
# 'invocate'
# '39'
# 'ist'
# 'deservst'
# 'teachest'
# '40'
# 'hadst'
# 'receivest'
# 'usest'
# 'deceivest'
# 'wilful'
# 'refusest'
# 'spites'
# '41'
# 'mightst'
# 'forbear'
# '42'
# 'knowst'
# 'suffring'
# 'heres'
# '43'
# 'unrespected'
# 'unseeing'
# '44'
# '45'
# 'presentabsent'
# 'recured'
# '46'
# 'impanelled'
# 'moiety'
# '47'
# 'famished'
# 'awakes'
# '48'
# 'thievish'
# '49'
# 'uprear'
# '50'
# 'plods'
# 'dully'
# 'wretch'
# '51'
# 'offence'
# 'perfectst'
# 'neigh'
# 'wilfulslow'
# '52'
# 'uplocked'
# 'carcanet'
# 'specialblest'
# '53'
# 'whereof'
# 'foison'
# '54'
# 'odour'
# 'unwooed'
# 'odours'
# '55'
# 'unswept'
# 'besmeared'
# 'sluttish'
# 'broils'
# 'alloblivious'
# '56'
# 'fulness'
# 'dulness'
# '57'
# 'worldwithoutend'
# '58'
# 'sufferance'
# 'privilage'
# 'selfdoing'
# '59'
# 'labouring'
# '60'
# 'pebbled'
# 'wherewith'
# '61'
# 'slumbers'
# 'sendst'
# '62'
# 'possesseth'
# 'beated'
# 'chopt'
# 'selfloving'
# '63'
# 'oerworn'
# 'steepy'
# 'hes'
# '64'
# 'richproud'
# 'outworn'
# 'downrased'
# '65'
# 'oersways'
# 'wrackful'
# 'battring'
# '66'
# 'jollity'
# 'shamefully'
# 'strumpeted'
# 'tonguetied'
# 'doctorlike'
# 'miscalled'
# '67'
# 'impiety'
# 'beggared'
# '68'
# 'sepulchres'
# 'anothers'
# '69'
# 'churls'
# 'matcheth'
# '70'
# 'presentst'
# '71'
# 'vilest'
# '72'
# '73'
# 'seest'
# 'fadeth'
# 'perceivst'
# '74'
# 'reviewest'
# 'wretchs'
# '75'
# 'sweetseasoned'
# 'twixt'
# 'enjoyer'
# 'filching'
# 'gluttoning'
# '76'
# '77'
# '78'
# 'poesy'
# 'learneds'
# '79'
# 'behaviour'
# '80'
# 'shallowest'
# 'soundless'
# '81'
# 'oerread'
# 'breathers'
# '82'
# 'attaint'
# 'oerlook'
# 'timebettering'
# 'truetelling'
# '83'
# '84'
# 'immured'
# 'dignifies'
# '85'
# 'unlettered'
# 'hindmost'
# '86'
# 'inhearse'
# 'compeers'
# '87'
# 'swerving'
# '88'
# 'attainted'
# 'doublevantage'
# '89'
# 'lameness'
# 'wronk'
# '90'
# 'afterloss'
# 'scaped'
# 'rearward'
# 'purposed'
# '91'
# 'humour'
# '92'
# 'blessedfair'
# '93'
# 'manys'
# '94'
# 'tibey'
# 'outbraves'
# 'sourest'
# '95'
# 'dispraise'
# 'illused'
# '96'
# 'wantonness'
# 'throned'
# 'gazers'
# '97'
# 'freezings'
# 'decembers'
# 'wombs'
# 'unfathered'
# '98'
# 'proudpied'
# 'lilys'
# '99'
# 'fearfully'
# 'colour'
# '100'
# 'forgetst'
# 'spendst'
# 'resty'
# 'preventst'
# '101'
# '102'
# 'merchandized'
# 'esteeming'
# 'philomel'
# 'burthens'
# '103'
# 'overgoes'
# '104'
# 'unbred'
# '105'
# '106'
# 'wights'
# 'blazon'
# 'prefiguring'
# '107'
# 'incertainties'
# '108'
# '109'
# 'preposterously'
# '110'
# 'blenches'
# '111'
# 'dyers'
# '112'
# 'oergreen'
# 'steeled'
# 'abysm'
# 'adders'
# 'flatterer'
# '113'
# 'effectually'
# 'rudst'
# 'deformedst'
# 'maketh'
# '114'
# 'saith'
# 'cherubins'
# 'greeing'
# '115'
# 'millioned'
# 'sharpst'
# 'altring'
# 'incertainty'
# '116'
# 'everfixed'
# 'tempests'
# 'wandring'
# '117'
# 'scanted'
# 'whereto'
# 'dearpurchased'
# 'wilfulness'
# 'wakened'
# '118'
# 'neercloying'
# 'meetness'
# '119'
# 'limbecks'
# '120'
# 'unkindness'
# 'yhave'
# '121'
# 'salutation'
# 'sportive'
# 'frailer'
# '122'
# 'charactered'
# 'forgetfulness'
# '123'
# 'wondring'
# '124'
# 'builded'
# 'thralled'
# 'shortnumbered'
# '125'
# 'weret'
# 'extern'
# 'honouring'
# 'savour'
# 'thrivers'
# 'oblation'
# 'suborned'
# '126'
# 'showst'
# 'goest'
# 'quietus'
# '127'
# 'fairing'
# 'profaned'
# '128'
# 'playst'
# 'swayst'
# '129'
# '130'
# 'damasked'
# '131'
# 'tyrannous'
# '132'
# 'beseem'
# '133'
# 'beshrew'
# 'sweetst'
# 'whoeer'
# 'rigour'
# 'gaol'
# '134'
# 'covetous'
# 'suretylike'
# 'putst'
# '135'
# 'overplus'
# 'addeth'
# 'beseechers'
# '136'
# 'lovesuit'
# 'fulfil'
# '137'
# 'overpartial'
# '138'
# 'untutored'
# 'unlearned'
# 'falsespeaking'
# '139'
# 'needst'
# 'oerpressed'
# '140'
# 'pitywanting'
# 'illwresting'
# 'slanderers'
# '141'
# '142'
# 'reproving'
# 'importune'
# 'selfexample'
# '143'
# 'huswife'
# 'prizing'
# 'runst'
# '144'
# 'worser'
# 'tempteth'
# '145'
# '146'
# 'inheritors'
# 'theres'
# '147'
# 'nurseth'
# 'franticmad'
# '148'
# 'censures'
# 'aright'
# 'keepst'
# 'wellseeing'
# '149'
# 'alltyrant'
# 'hateth'
# 'frownst'
# 'lourst'
# '150'
# 'insufficiency'
# 'warrantise'
# 'unworthiness'
# '151'
# '152'
# 'bedvow'
# '153'
# 'dians'
# 'lovekindling'
# 'valleyfountain'
# 'seeting'
# 'newfired'
# 'withal'
# 'thither'
# 'hied'
# 'distempered'
# '154'
# 'lovegod'
# 'heartinflaming'
# 'votary'
# 'quenched'
# 'discased'
# 'deaddoing'
# 'closebleeding'
# 'bathd'
# 'longlacked'
# 'unquiet'
# 'lovepined'
# 'sithens'
# 'woxen'
# 'lurkest'
# 'succour'
# 'humbless'
# 'entreat'
# 'baseness'
# 'ravished'
# 'fancys'
# 'endite'
# 'dumpish'
# 'cheerless'
# 'dight'
# 'wrongest'
# 'sdeigne'
# 'portliness'
# 'boldened'
# 'selfpleasing'
# 'lusts'
# 'durefull'
# 'dints'
# 'mazed'
# 'ensample'
# 'longwhile'
# 'thimage'
# 'persever'
# 'mought'
# 'likest'
# 'unrighteous'
# 'makest'
# 'lordeth'
# 'freewill'
# 'scorning'
# 'tyraness'
# 'comptroll'
# 'renewth'
# 'persueth'
# 'unpityed'
# 'assoyle'
# 'surcease'
# 'heartthrilling'
# 'treasons'
# 'guileful'
# 'eyen'
# 'tabide'
# 'captiving'
# 'graceth'
# 'embaseth'
# 'descry'
# 'remembreth'
# 'lothsome'
# 'drossy'
# 'lowliness'
# 'abondond'
# 'needeth'
# 'belay'
# 'enurd'
# 'plaints'
# 'tradefull'
# 'indias'
# 'saphires'
# 'forhead'
# 'weene'
# 'unwarily'
# 'stonished'
# 'archers'
# 'misintended'
# 'embase'
# 'colours'
# 'eyeglances'
# 'pleasance'
# 'craftsmans'
# 'thereto'
# 'runneth'
# 'drizling'
# 'plaint'
# 'resounded'
# 'mongst'
# 'disobeys'
# 'reighneth'
# 'lioness'
# 'defiled'
# 'cruelness'
# 'meekness'
# 'tadorn'
# 'recure'
# 'thauthor'
# 'godess'
# 'wooers'
# 'unreave'
# 'thimportune'
# 'rend'
# 'unwares'
# 'intreat'
# 'doubtfully'
# 'meede'
# 'pricketh'
# 'firbloom'
# 'broomflower'
# 'sith'
# 'beseen'
# 'fleshs'
# 'thessalian'
# 'revengeful'
# 'quoth'
# 'meeds'
# 'therewith'
# 'sohot'
# 'depraves'
# 'scath'
# 'allurement'
# 'thralls'
# 'embrew'
# 'abhored'
# 'thanvil'
# 'frieseth'
# 'faedry'
# 'aread'
# 'theaccomplishment'
# 'troublous'
# 'whenas'
# 'plast'
# 'carefull'
# 'comfortless'
# 'pensiveness'
# 'covetize'
# 'starvd'
# 'seemeth'
# 'langor'
# 'aswagement'
# 'shewed'
# 'extermities'
# 'dispise'
# 'cunningly'
# 'craftily'
# 'rashly'
# 'arion'
# 'pitty'
# 'blamd'
# 'wonts'
# 'jove'
# 'thundring'
# 'shinedst'
# 'gladness'
# 'whylest'
# 'tincrease'
# 'wretches'
# 'piteous'
# 'foully'
# 'tormenteth'
# 'extremest'
# 'augmenteth'
# 'captived'
# 'lovelearned'
# 'whilest'
# 'warried'
# 'aslake'
# 'tuneless'
# 'despight'
# 'immortally'
# 'visnomy'
# 'abodes'
# 'prefixed'
# 'aswage'
# 'guilefull'
# 'heretics'
# 'contrained'
# 'requite'
# 'thutmost'
# 'cockatrices'
# 'footstool'
# 'priefe'
# 'langour'
# 'excellect'
# 'assayed'
# 'tachieve'
# 'despoiled'
# 'knowen'
# 'languor'
# 'thm'
# 'enbrew'
# 'diversely'
# 'flits'
# 'rues'
# 'greediness'
# 'felly'
# 'pityless'
# 'stoures'
# 'wouds'
# 'lviii'
# 'thassurance'
# 'reposeth'
# 'scorneth'
# 'supposeth'
# 'unstayed'
# 'changeful'
# 'glorys'
# 'faileth'
# 'standeth'
# 'endurence'
# 'misdeem'
# 'outwent'
# 'languishment'
# 'taccuse'
# 'upbrought'
# 'lovd'
# 'compassed'
# 'betokening'
# 'forepast'
# 'glooming'
# 'gladsome'
# 'sufficeth'
# 'damsels'
# 'gillyflowers'
# 'budded'
# 'bellamores'
# 'lillies'
# 'jasmines'
# 'blissing'
# 'plenteous'
# 'disparagement'
# 'matchable'
# 'enlumined'
# 'halftrembling'
# 'harrowed'
# 'worthily'
# 'antick'
# 'valorous'
# 'emprize'
# 'adornd'
# 'coatarmor'
# 'forelock'
# 'misseth'
# 'amearst'
# 'drawen'
# 'youself'
# 'woodbine'
# 'mantleth'
# 'flys'
# 'encage'
# 'framd'
# 'derivd'
# 'elizabeths'
# 'doest'
# 'eek'
# 'quod'
# 'eternize'
# 'paps'
# 'loosly'
# 'juncats'
# 'unvalued'
# 'thereunto'
# 'faery'
# 'fordone'
# 'handmaid'
# 'queene'
# 'heares'
# 'richladen'
# 'soom'
# 'enchased'
# 'lustfull'
# 'sprites'
# 'plights'
# 'venemous'
# 'furies'
# 'snaky'
# 'accursed'
# 'falseforged'
# 'meed'
# 'noyous'
# 'reascend'
# 'thonly'
# 'loveafamished'
# 'disconsolate'
# 'unspotted'
# 'pleasauns'
# {'from': '1', 'fairest': '10', 'creatures': '10', 'we': '1', 'desire': '010', 'increase': '01', 'that': '1', 'thereby': '11', 'rose': '1', 'might': '1', 'never': '10', 'die': '1', 'but': '1', 'as': '1', 'the': '0', 'should': '1', 'by': '1', 'time': '1', 'decease': '01', 'his': '1', 'tender': '10', 'heir': '1', 'bear': '1', 'memory': '100', 'thou': '1', 'contracted': '100', 'to': '1', 'thine': '1', 'own': '1', 'bright': '1', 'eyes': '1', 'thy': '1', 'lights': '1', 'flame': '1', 'with': '1', 'fuel': '10', 'making': '10', 'a': '0', 'famine': '10', 'where': '1', 'abundance': '010', 'lies': '1', 'self': '1', 'foe': '1', 'sweet': '1', 'too': '1', 'cruel': '10', 'art': '1', 'now': '1', 'worlds': '1', 'fresh': '1', 'ornament': '100', 'and': '0', 'only': '10', 'herald': '10', 'gaudy': '10', 'spring': '1', 'within': '01', 'bud': '1', 'content': '10', 'waste': '1', 'in': '0', 'pity': '10', 'world': '1', 'or': '1', 'else': '1', 'this': '1', 'be': '1', 'eat': '1', 'due': '1', 'grave': '1', 'thee': '1', 'when': '1', 'forty': '10', 'winters': '10', 'shall': '1', 'besiege': '01', 'brow': '1', 'dig': '1', 'deep': '1', 'trenches': '10', 'field': '1', 'youths': '1', 'proud': '1', 'livery': '100', 'so': '1', 'gazed': '1', 'on': '1', 'will': '1', 'tattered': '10', 'weed': '1', 'of': '1', 'small': '1', 'worth': '1', 'held': '1', 'then': '1', 'being': '10', 'asked': '1', 'all': '1', 'beauty': '10', 'treasure': '10', 'lusty': '10', 'days': '1', 'say': '1', 'sunken': '10', 'were': '0', 'an': '1', 'shame': '1', 'praise': '1', 'how': '1', 'much': '1', 'more': '1', 'deserved': '01', 'use': '1', 'if': '1', 'answer': '10', 'fair': '1', 'child': '1', 'mine': '1', 'sum': '1', 'my': '1', 'count': '1', 'make': '1', 'old': '1', 'excuse': '01', 'proving': '10', 'succession': '010', 'new': '1', 'made': '1', 'see': '1', 'blood': '1', 'warm': '1', 'it': '1', 'cold': '1', 'look': '1', 'glass': '1', 'tell': '1', 'face': '1', 'is': '1', 'form': '1', 'another': '010', 'whose': '1', 'repair': '01', 'not': '1', 'dost': '1', 'beguile': '01', 'some': '1', 'mother': '10', 'for': '1', 'she': '1', 'womb': '1', 'disdains': '01', 'husbandry': '100', 'who': '1', 'he': '1', 'fond': '1', 'tomb': '1', 'stop': '1', 'posterity': '0100', 'mothers': '10', 'calls': '1', 'back': '1', 'lovely': '10', 'april': '10', 'her': '0', 'prime': '1', 'through': '1', 'windows': '10', 'age': '1', 'shalt': '1', 'despite': '01', 'wrinkles': '10', 'golden': '10', 'live': '1', 'remembered': '010', 'single': '10', 'image': '10', 'dies': '1', 'why': '1', 'spend': '1', 'upon': '01', 'legacy': '100', 'natures': '10', 'bequest': '01', 'gives': '1', 'nothing': '10', 'doth': '1', 'lend': '1', 'frank': '1', 'lends': '1', 'those': '1', 'are': '1', 'free': '1', 'niggard': '10', 'abuse': '01', 'largess': '10', 'given': '10', 'give': '1', 'great': '1', 'sums': '1', 'yet': '1', 'having': '10', 'traffic': '10', 'alone': '01', 'deceive': '01', 'nature': '10', 'gone': '1', 'what': '1', 'acceptable': '0100', 'audit': '10', 'leave': '1', 'unused': '01', 'must': '1', 'which': '1', 'used': '1', 'lives': '1', 'th': '11', 'executor': '0100', 'hours': '10', 'gentle': '10', 'work': '1', 'did': '1', 'frame': '1', 'gaze': '1', 'every': '100', 'eye': '1', 'dwell': '1', 'play': '1', 'tyrants': '10', 'very': '10', 'same': '1', 'unfair': '01', 'fairly': '10', 'excel': '01', 'leads': '1', 'summer': '10', 'hideous': '100', 'winter': '10', 'confounds': '01', 'him': '1', 'there': '1', 'sap': '1', 'checked': '1', 'frost': '1', 'leaves': '1', 'quite': '1', 'summers': '10', 'distillation': '010', 'left': '1', 'liquid': '10', 'prisoner': '100', 'pent': '1', 'walls': '1', 'effect': '01', 'bereft': '01', 'nor': '1', 'no': '1', 'remembrance': '010', 'was': '1', 'flowers': '10', 'distilled': '01', 'though': '1', 'they': '1', 'meet': '1', 'leese': '1', 'their': '1', 'show': '1', 'substance': '10', 'still': '1', 'let': '1', 'ragged': '10', 'hand': '1', 'deface': '01', 'ere': '1', 'vial': '10', 'place': '1', 'forbidden': '100', 'usury': '100', 'pay ...

# %% [markdown]
# # Poetry Generation

# %%
states = 12
iterations = 30
x, mapping =  parse_map(lines)
HMM = hmm.unsupervised_HMM(x, states, iterations)
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29

# %%
x, mapping = parse_map(lines)
mapping_r =  mapping_reverser(mapping)

poem_length = 14
syllable_length = 10

random.seed(1999)
r = np.random.choice(list(rhyme_dic.keys()), size=(7,), replace=False)
r = np.array(r)
print(r)
rhyme_scheme = [r[0], r[1], r[0], r[1], r[2], r[3], r[2], r[3], r[4], r[5], r[4], r[5], r[6], r[6]]
states_sonnet = []
emission_sonnet = []
for i in range(poem_length): 
    emission, state = HMM.generate_emission_rhyme_meter(syllable_length, mapping, mapping_r, rhyme_scheme[i], rhyme_dic, stress_dic)
    sentence = [mapping_r[i] for i in list(emission)]
    states_sonnet.append(list(state))
    emission_sonnet.append(list(emission))
    print(' '.join(sentence).capitalize())
# Out:
# ['UW' 'AE' 'IY' 'AH' 'UH' 'OW' 'ER']
# And silver one and public by and used
# And art and death the thou and mention cast
# And even thou her pride and blunting true
# In is and of divine upon entrap
# A spacious ah and wanting eyes and reap
# By her hush the given every hush
# Were cover praising feeble streams a streams
# Shames and heavenly blessings heavy drudge
# And lease and harden where entrap allured
# The shows and than in true the you the shows
# Her lesson painting to the hush and puts
# And my the lives and linger hush enclose
# And at her birth allured the birth and birth
# A true a wailing when in numbers hearst

# %% [markdown]
# # Analysis

# %%
# for each of the 5 randomly chosen states, write the top 10 words by probability
# We will just use state 0,1,2,3,4 for convenience
for i in range(12):
    top_10_idx = np.argsort(HMM.O[i])[-10:]
    top_10_idx = reversed(top_10_idx)
    top_10_words = [mapping_r[i] for i in top_10_idx]
    print('state ' + str(i))
    print(top_10_words)
# note that these might be different from what's in the report since we've ran hmm multiple times
# Out:
# state 0
# ['and', 'but', 'or', 'for', 'which', 'that', 'so', 'then', 'to', 'thus']
# state 1
# ['birth', 'drudge', 'true', 'love', 'self', 'heart', 'eyes', 'doth', 'life', 'beauty']
# state 2
# ['used', 'allured', 'but', 'and', 'if', 'o', 'when', 'yet', 'for', 'then']
# state 3
# ['and', 'that', 'but', 'for', 'so', 'than', 'yet', 'to', 'when', 'nor']
# state 4
# ['allured', 'in', 'thou', 'all', 'that', 'for', 'like', 'when', 'as', 'those']
# state 5
# ['puts', 'drudge', 'entrap', 'shows', 'i', 'true', 'used', 'to', 'that', 'not']
# state 6
# ['streams', 'cast', 'allured', 'i', 'be', 'have', 'me', 'thee', 'to', 'by']
# state 7
# ['birth', 'hush', 'shows', 'thou', 'thee', 'with', 'his', 'by', 'love', 'more']
# state 8
# ['hearst', 'enclose', 'reap', 'and', 'the', 'true', 'to', 'with', 'so', 'but']
# state 9
# ['true', 'the', 'my', 'thy', 'her', 'your', 'their', 'this', 'all', 'me']
# state 10
# ['true', 'shows', 'is', 'a', 'of', 'it', 'mine', 'so', 'thou', 'art']
# state 11
# ['shows', 'of', 'in', 'to', 'with', 'true', 'from', 'for', 'on', 'that']

# %%
from HMM_helper import (
    text_to_wordcloud,
#     states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

import os
from IPython.display import HTML

visualize_sparsities(HMM, O_max_cols=50)

# %%
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib import animation
from matplotlib.animation import FuncAnimation

def mask():
    # Parameters.
    r = 128
    d = 2 * r + 1

    # Get points in a circle.
    y, x = np.ogrid[-r:d-r, -r:d-r]
    circle = (x**2 + y**2 <= r**2)

    # Create mask.
    mask = 255 * np.ones((d, d), dtype=np.uint8)
    mask[circle] = 0

    return mask

def text_to_wordcloud(text, max_words=50, title='', show=True):
    plt.close('all')

    # Generate a wordcloud image.
    wordcloud = WordCloud(random_state=0,
                          max_words=max_words,
                          background_color='white',
                          mask=mask()).generate(text)

    # Show the image.
    if show:
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title, fontsize=24)
        plt.show()

    return wordcloud

def states_to_wordclouds(hmm, mapping_r, max_words=50, show=True):
    wordclouds = []
    for i in range(12):
#         idx = np.random.choice(range(hmm.D), size=(30, ), replace=False)
#         words = [mapping_r[i] for i in idx]
        idx = np.argsort(hmm.O[i])[-max_words:]
        words = [mapping_r[i] for i in idx]
        sentence_str = ' '.join(words)
        wordclouds.append(text_to_wordcloud(sentence_str, max_words=max_words, title='State %d' % i, show=show))

# %%
wordclouds = states_to_wordclouds(HMM, mapping_r)

# %%
def animate_emission(hmm, obs_map, wordclouds, emission, states, M=8, height=12, width=12, delay=1, n_states=12):
    # Parameters.
    lim = 1200
    text_x_offset = 40
    text_y_offset = 80
    x_offset = 580
    y_offset = 520
    R = 420
    r = 100
    arrow_size = 20
    arrow_p1 = 0.03
    arrow_p2 = 0.02
    arrow_p3 = 0.06
    

    # Initialize plot.    
    fig, ax = plt.subplots()
    fig.set_figheight(height)
    fig.set_figwidth(width)
    ax.grid('off')
    plt.axis('off')
    ax.set_xlim([0, lim])
    ax.set_ylim([0, lim])

    # Plot each wordcloud.
    for i, wordcloud in enumerate(wordclouds):
        x = x_offset + int(R * np.cos(np.pi * 2 * i / n_states))
        y = y_offset + int(R * np.sin(np.pi * 2 * i / n_states))
        ax.imshow(wordcloud.to_array(), extent=(x - r, x + r, y - r, y + r), aspect='auto', zorder=-1)

    # Initialize text.
    text = ax.text(text_x_offset, lim - text_y_offset, '', fontsize=24)
        
    # Make the arrows.
    zorder_mult = n_states ** 2 * 100
    arrows = []
    for i in range(n_states):
        row = []
        for j in range(n_states):
            # Arrow coordinates.
            x_i = x_offset + R * np.cos(np.pi * 2 * i / n_states)
            y_i = y_offset + R * np.sin(np.pi * 2 * i / n_states)
            x_j = x_offset + R * np.cos(np.pi * 2 * j / n_states)
            y_j = y_offset + R * np.sin(np.pi * 2 * j / n_states)
            
            dx = x_j - x_i
            dy = y_j - y_i
            d = np.sqrt(dx**2 + dy**2)

            if i != j:
                arrow = ax.arrow(x_i + (r/d + arrow_p1) * dx + arrow_p2 * dy,
                                 y_i + (r/d + arrow_p1) * dy + arrow_p2 * dx,
                                 (1 - 2 * r/d - arrow_p3) * dx,
                                 (1 - 2 * r/d - arrow_p3) * dy,
                                 color=(1 - hmm.A[i][j], ) * 3,
                                 head_width=arrow_size, head_length=arrow_size,
                                 zorder=int(hmm.A[i][j] * zorder_mult))
            else:
                arrow = ax.arrow(x_i, y_i, 0, 0,
                                 color=(1 - hmm.A[i][j], ) * 3,
                                 head_width=arrow_size, head_length=arrow_size,
                                 zorder=int(hmm.A[i][j] * zorder_mult))

            row.append(arrow)
        arrows.append(row)

    emission, states = hmm.generate_emission(M)

    def animate(i):
        if i >= delay:
            i -= delay

            if i == 0:
                arrows[states[0]][states[0]].set_color('red')
            elif i == 1:
                arrows[states[0]][states[0]].set_color((1 - hmm.A[states[0]][states[0]], ) * 3)
                arrows[states[i - 1]][states[i]].set_color('red')
            else:
                arrows[states[i - 2]][states[i - 1]].set_color((1 - hmm.A[states[i - 2]][states[i - 1]], ) * 3)
                arrows[states[i - 1]][states[i]].set_color('red')

            # Set text.
            text.set_text(' '.join([obs_map_r[e] for e in emission][:i+1]).capitalize())

            return arrows + [text]

    # Animate!
    print('\nAnimating...')
    anim = FuncAnimation(fig, animate, frames=M+delay, interval=1000)

    return anim

# %%
anim = animate_emission(HMM, mapping_r, wordclouds, emission,  M=8)
HTML(anim.to_html5_video())
# Out:
# [[2, 4, 10, 3, 8, 7, 0, 2], [3, 7, 8, 7, 8, 7, 0, 5, 6], [0, 3, 4, 9, 1, 3, 4, 10], [4, 10, 3, 8, 7, 0, 5], [11, 7, 0, 3, 9, 1, 3, 8], [6, 11, 7, 8, 7, 8, 7], [5, 6, 6, 6, 6, 6, 6], [0, 3, 4, 11, 9, 1], [8, 7, 8, 7, 0, 5, 6], [8, 7, 0, 3, 4, 10, 8, 7, 8, 7], [9, 1, 3, 4, 9, 7, 0, 5], [3, 9, 9, 1, 3, 8, 7, 8], [0, 4, 9, 1, 11, 9, 1, 3, 7], [10, 10, 10, 1, 3, 4, 10, 8]]

# %% [markdown]
# 1) not all words are likely to be the first word
# 2) keep sonnet rhyme by discarding words until the right format is found (abab cdcd efef gg)
# 3) keep stressed / unstressed by discarding until you find the correct one
#
# problems:
# 1) after rhyming and meter are fixed tightly (discarding unqualified words), the poem makes less sense,
# the starting word becomes some frequent words like "And" "In" (prob trying to find the word with just right sylable, so less choice)
